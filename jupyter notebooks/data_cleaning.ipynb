# %%
import pandas as pd
import numpy as np

# %%
df1 = df2 = pd.read_excel("../Dataset/only total DB.xlsx")

# %%
df1.head(10)
# Out:
#    Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 0  2019          396004.648       177140.029                  38202.140680
# 1  2018          371783.046       164846.794                  37716.474900
# 2  2017          354117.846       150807.784                  35129.055463
# 3  2016          359490.000       149378.000                  37177.000000
# 4  2015          328148.000       136060.000                  34350.000000
# 5  2014          321560.000       148813.000                  36910.000000
# 6  2013          279310.000       136329.000                  32439.000000
# 7  2012          257088.000       137086.000                  31528.000000
# 8  2011          216672.000       114905.000                  28163.000000
# 9  2010          193436.000       101976.000                  27264.000000
#
#    Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 0     54898.469                  1427773.250             902151.9924
# ...

# %%
df1.columns
# Out:
# Index(['Year', 'Total Multilateral', 'Total Bilateral',
#        ' International Monetary Fund', 'Trade Credit',
#        'Total Commercial Borrowings', 'NRI & FC(B&O) Deposits', 'Rupee Debt',
#        'Total Long-Term Debt', 'Total Short-Term debt', 'Gross Total Debt'],
#       dtype='object')

# %%
drop_columns = [df1.columns[::-1][0],df1.columns[::-1][1]]
print(drop_columns)
# Out:
# ['Gross Total Debt', 'Total Short-Term debt']

# %%
df1.drop(drop_columns,inplace=True,axis=1)

# %%
df1.head(10)
# Out:
#    Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 0  2019          396004.648       177140.029                  38202.140680
# 1  2018          371783.046       164846.794                  37716.474900
# 2  2017          354117.846       150807.784                  35129.055463
# 3  2016          359490.000       149378.000                  37177.000000
# 4  2015          328148.000       136060.000                  34350.000000
# 5  2014          321560.000       148813.000                  36910.000000
# 6  2013          279310.000       136329.000                  32439.000000
# 7  2012          257088.000       137086.000                  31528.000000
# 8  2011          216672.000       114905.000                  28163.000000
# 9  2010          193436.000       101976.000                  27264.000000
#
#    Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 0     54898.469                  1427773.250             902151.9924
# ...

# %%
df1.replace(0,np.nan,inplace=True)

# %%
df1.head(30)
# Out:
#     Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 0   2019          396004.648       177140.029                  38202.140680
# 1   2018          371783.046       164846.794                  37716.474900
# 2   2017          354117.846       150807.784                  35129.055463
# 3   2016          359490.000       149378.000                  37177.000000
# 4   2015          328148.000       136060.000                  34350.000000
# 5   2014          321560.000       148813.000                  36910.000000
# 6   2013          279310.000       136329.000                  32439.000000
# 7   2012          257088.000       137086.000                  31528.000000
# 8   2011          216672.000       114905.000                  28163.000000
# 9   2010          193436.000       101976.000                  27264.000000
# 10  2009          201425.000       104997.000                   5188.000000
# ...

# %%
df1.mean()
# Out:
# Year                              2005.000000
# Total Multilateral              186044.673793
# Total Bilateral                  93627.227828
#  International Monetary Fund     16981.487348
# Trade Credit                     43433.076414
# Total Commercial Borrowings     384461.941414
# NRI & FC(B&O) Deposits          257637.930069
# Rupee Debt                       15512.247465
# Total Long-Term Debt            995941.878759
# dtype: float64

# %%
df1.fillna(df1.mean(),inplace=True)

# %%
df1[20:25]
# Out:
#     Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 20  1999            129682.0          74304.0                        1218.0
# 21  1998            116904.0          67104.0                        2622.0
# 22  1997            105066.0          62891.0                        4714.0
# 23  1996             98173.0          65740.0                        8152.0
# 24  1995             89819.0          63761.0                       13545.0
#
#     Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 20       28812.0                      89019.0                 50048.0
# 21       25783.0                      67086.0                 47050.0
# 22       21044.0                      51454.0                 39527.0
# 23       18432.0                      47642.0                 37802.0
# 24       20876.0                      40915.0                 39006.0
#
#     Rupee Debt  Total Long-Term Debt
# 20     20077.0              393160.0
# ...

# %%
df1=df1[::-1]

# %%
df1.head()
# Out:
#     Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 28  1991             40386.0          27378.0                        5132.0
# 27  1992             68262.0          47603.0                        8934.0
# 26  1993             77758.0          50258.0                       14985.0
# 25  1994             82199.0          54580.0                       15812.0
# 24  1995             89819.0          63761.0                       13545.0
#
#     Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 28        8374.0                      19727.0                 20030.0
# 27       12418.0                      35711.0                 27384.0
# 26       13484.0                      36367.0                 34941.0
# 25       16307.0                      38782.0                 39729.0
# 24       20876.0                      40915.0                 39006.0
#
#     Rupee Debt  Total Long-Term Debt
# 28     25199.0              146226.0
# ...

# %%
df1.index=[i for i in range(0,29)]

# %%
df1.head()
# Out:
#    Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 0  1991             40386.0          27378.0                        5132.0
# 1  1992             68262.0          47603.0                        8934.0
# 2  1993             77758.0          50258.0                       14985.0
# 3  1994             82199.0          54580.0                       15812.0
# 4  1995             89819.0          63761.0                       13545.0
#
#    Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 0        8374.0                      19727.0                 20030.0
# 1       12418.0                      35711.0                 27384.0
# 2       13484.0                      36367.0                 34941.0
# 3       16307.0                      38782.0                 39729.0
# 4       20876.0                      40915.0                 39006.0
#
#    Rupee Debt  Total Long-Term Debt
# 0     25199.0              146226.0
# ...

# %%
df1.to_csv("cleaned_data.csv")

# %%
df2.head()
# Out:
#    Year  Total Multilateral  Total Bilateral   International Monetary Fund  \
# 0  2019          396004.648       177140.029                  38202.140680
# 1  2018          371783.046       164846.794                  37716.474900
# 2  2017          354117.846       150807.784                  35129.055463
# 3  2016          359490.000       149378.000                  37177.000000
# 4  2015          328148.000       136060.000                  34350.000000
#
#    Trade Credit  Total Commercial Borrowings  NRI & FC(B&O) Deposits  \
# 0     54898.469                  1427773.250             902151.9924
# 1     61659.731                  1312755.900             820737.1694
# 2     62426.016                  1115514.151             757750.8102
# 3     70001.000                  1197176.000             841956.0000
# 4     78915.000                  1128501.000             720997.0000
#
#    Rupee Debt  Total Long-Term Debt
# 0  8006.83892          3.004177e+06
# ...
